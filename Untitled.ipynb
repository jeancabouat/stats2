# %%
! pip install -qr requirements.txt
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from functions import query

# %%
df_insee_ref = query(f"SELECT * FROM insee_ref")
df_insee_ref.head()
# Out:
#   id_dep libDep  id_reg                libReg id_com                   libCom  \
# 0     01    Ain      84  Auvergne-Rhône-Alpes  01001  L'Abergement-Clémenciat
# 1     01    Ain      84  Auvergne-Rhône-Alpes  01002    L'Abergement-de-Varey
# 2     01    Ain      84  Auvergne-Rhône-Alpes  01004        Ambérieu-en-Bugey
# 3     01    Ain      84  Auvergne-Rhône-Alpes  01005      Ambérieux-en-Dombes
# 4     01    Ain      84  Auvergne-Rhône-Alpes  01006                  Ambléon
#
#   id_cir type_com
# 0  01004  entière
# 1  01005  entière
# 2  01005  entière
# 3  01004  entière
# 4  01003  entière

# %%
# %%writefile app.py

import sys
sys.path.append('/content/drive/MyDrive/Colab_Notebooks')

import functions
from functions import *

import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=pd.errors.SettingWithCopyWarning)

import streamlit as st
import pandas as pd
import numpy as np

# ref INSEE
df_insee_ref = query(f"SELECT * FROM insee_ref")

option = st.selectbox(
    "Région:",
    df_insee_ref['libReg'].unique().tolist(), # Use the 'Email' column as options
    index=None,
    placeholder="Selectionner une région",
)

st.write("Région sélectionnée:", option)
# Out:
# Overwriting app.py

# %%
# !npm install localtunnel
# Out:
# m#################⠂) ⠇ reify:yargs-parser: http fetch GET 200 https://registry.
# added 22 packages in 1s
#
# 3 packages are looking for funding
#   run `npm fund` for details
# npm notice
# npm notice New major version of npm available! 9.8.1 -> 11.6.2
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v11.6.2
# npm notice Run npm install -g npm@11.6.2 to update!
# npm notice

# %%
# !streamlit run app.py &>/content/logs.txt &
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 get_ipython().system('streamlit run app.py &>/content/logs.txt &')
#
# File ~/.local/lib/python3.12/site-packages/ipykernel/zmqshell.py:641, in ZMQInteractiveShell.system_piped(self, cmd)
#     634 if cmd.rstrip().endswith("&"):
#     635     # this is *far* from a rigorous test
#     636     # We do not support backgrounding processes because we either use
#     637     # pexpect or pipes to read from.  Users can always just call
#     638     # os.system() or use ip.system=ip.system_raw
#     639     # if they really want a background process.
#     640     msg = "Background processes not supported."
# --> 641     raise OSError(msg)
#     643 # we explicitly do NOT return the subprocess status code, because
#     644 # a non-None value would trigger :func:`sys.displayhook` calls.
#     645 # Instead, we store the exit_code in user_ns.
#     646 # Also, protect system call from UNC paths on Windows here too
#     647 # as is done in InteractiveShell.system_raw
#     648 if sys.platform == "win32":
#
# OSError: Background processes not supported.
